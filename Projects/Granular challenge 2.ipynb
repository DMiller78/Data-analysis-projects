# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv("/Users/mille/Desktop/cdl_fresno.csv")

# %%
df.head()
# Out:
#    Value       Cat  Total_count  Land_Acreage
# 0      1      Corn        45983       10226.4
# 1      2    Cotton       467521      103974.2
# 2      3      Rice           16           3.6
# 3      4   Sorghum         4240         943.0
# 4     21    Barley        93522       20798.8

# %%
df.describe()
# Out:
#             Value   Total_count   Land_Acreage
# count   65.000000  6.500000e+01      65.000000
# mean   120.723077  1.397979e+05   31090.296923
# std     81.254713  2.729382e+05   60699.990681
# min      1.000000  1.000000e+00       0.200000
# 25%     48.000000  1.787000e+03     397.400000
# 50%    121.000000  1.127900e+04    2508.400000
# 75%    209.000000  9.352200e+04   20798.800000
# max    242.000000  1.139517e+06  253422.500000

# %%
sns.set_palette("GnBu_d")
sns.set_style('whitegrid')

# %%
sns.pairplot(df)

# %%
sns.lmplot(x='Total_count',y='Land_Acreage',data=df)
# Out:
# C:\Users\mille\Conda3\lib\site-packages\scipy\stats\stats.py:1633: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.set_style('whitegrid')
df['Total_count'].hist(bins=30)
plt.xlabel('Counts')
# Out:
# Text(0.5,0,'Counts')

# %%
sns.set_style('whitegrid')
df['Land_Acreage'].hist(bins=30)
plt.xlabel('Acreage')
# Out:
# Text(0.5,0,'Acreage')

# %%
sns.jointplot(x='Total_count',y='Land_Acreage',data=df)
# Out:
# C:\Users\mille\Conda3\lib\site-packages\scipy\stats\stats.py:1633: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.pairplot(df,hue='Cat',palette='bwr')

# %%
plt.figure(figsize=(20, 15))

ax = sns.barplot(x="Land_Acreage", y="Cat", data=df)
# Out:
# C:\Users\mille\Conda3\lib\site-packages\seaborn\categorical.py:1460: FutureWarning: remove_na is deprecated and is a private function. Do not use.
#   stat_data = remove_na(group_data)

# %%
plt.figure(figsize=(20, 15))

ax = sns.barplot(x="Total_count", y="Cat", data=df)
# Out:
# C:\Users\mille\Conda3\lib\site-packages\seaborn\categorical.py:1460: FutureWarning: remove_na is deprecated and is a private function. Do not use.
#   stat_data = remove_na(group_data)

# %%
sns.distplot(df['Land_Acreage'].dropna(),kde=False,color='darkred',bins=50)

# %%
df[['Total_count', 'Land_Acreage']].describe()
# Out:
#         Total_count   Land_Acreage
# count  6.500000e+01      65.000000
# mean   1.397979e+05   31090.296923
# std    2.729382e+05   60699.990681
# min    1.000000e+00       0.200000
# 25%    1.787000e+03     397.400000
# 50%    1.127900e+04    2508.400000
# 75%    9.352200e+04   20798.800000
# max    1.139517e+06  253422.500000

# %%
df.corr()
# Out:
#                  Value  Total_count  Land_Acreage
# Value         1.000000    -0.088635     -0.088635
# Total_count  -0.088635     1.000000      1.000000
# Land_Acreage -0.088635     1.000000      1.000000

# %%
sns.distplot(df['Land_Acreage'])
# Out:
# C:\Users\mille\Conda3\lib\site-packages\scipy\stats\stats.py:1633: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.distplot(df['Total_count'])
# Out:
# C:\Users\mille\Conda3\lib\site-packages\scipy\stats\stats.py:1633: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.heatmap(df.corr(),cmap='coolwarm',annot=True)

# %%
df = pd.read_csv("/Users/mille/Desktop/cdl_fresno.csv")

Crop_value = df.groupby('Crop_value').mean()
Crop_value
# Out:
#             Total_count  Land_Acreage
# Crop_value
# 1                 45983       10226.4
# 2                467521      103974.2
# 3                    16           3.6
# 4                  4240         943.0
# 21                93522       20798.8
# 22                 1787         397.4
# 23                 3649         811.5
# 24               446649       99332.3
# 27                   15           3.3
# 28                22636        5034.1
# 33                27551        6127.2
# 36               382575       85082.6
# 37                19574        4353.2
# 42                11279        2508.4
# 44                  622         138.3
# 46                   59          13.1
# 48                  234          52.0
# 49                72295       16078.0
# 54               230012       51153.4
# 57                 2505         557.1
# 59                  625         139.0
# 61               870212      193530.5
# 66                10407        2314.5
# ...

# %%
Crop_value.corr()
# Out:
#               Total_count  Land_Acreage
# Total_count           1.0           1.0
# Land_Acreage          1.0           1.0

# %%
df.mean()
# Out:
# Crop_value         120.723077
# Total_count     139797.876923
# Land_Acreage     31090.296923
# dtype: float64

# %%
df.var()
# Out:
# Crop_value      6.602328e+03
# Total_count     7.449525e+10
# Land_Acreage    3.684489e+09
# dtype: float64

# %%
df.shape
# Out:
# (65, 4)
